# %%
# !pip install google-play-scraper
# Out:
# Collecting google-play-scraper
#   Downloading google_play_scraper-1.2.7-py3-none-any.whl.metadata (50 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.2/50.2 kB 1.8 MB/s eta 0:00:00
# Downloading google_play_scraper-1.2.7-py3-none-any.whl (28 kB)
# Installing collected packages: google-play-scraper
# Successfully installed google-play-scraper-1.2.7

# %%
from google_play_scraper import reviews
from google_play_scraper import Sort
import pandas as pd



APP_ID   = 'com.gojek.app'   
N_DATA   = 300000            
LANG     = 'id'              
COUNTRY  = 'id'              
BATCH    = 200               


all_reviews = []
count = 0

while count < N_DATA:
  
    batch_reviews, _ = reviews(
        APP_ID,
        lang=LANG,
        country=COUNTRY,
        sort=Sort.NEWEST,
        count=BATCH,
        continuation_token=None  
    )
    all_reviews.extend(batch_reviews)
    count = len(all_reviews)

  
    if len(batch_reviews) < BATCH:
        break  


all_reviews = all_reviews[:N_DATA]
app_reviews_df = pd.DataFrame(all_reviews)
app_reviews_df.to_csv('review_gojek.csv', index=False, header=True)

print(f"Total review tersimpan: {len(app_reviews_df)}")
display(app_reviews_df.head())
# Out:
# Total review tersimpan: 300000
#                                reviewId                     userName  \
# 0  a7440532-5390-42d1-b9ad-03db5fdb4abb                Asep Suparman
# 1  b8bae157-6541-4491-831b-3506dc157293              Mas Bes Mas Bes
# 2  f8382452-892b-411c-b255-50a30ed8408f  Belajar Akuntansi Itu Mudah
# 3  19e6607c-bbbd-4bea-a341-a33c257f37a1                Kurni Berlian
# 4  361dfd8f-4b7e-43d7-96cd-bc5686390179                Mety Todingan
#
#                                            userImage  \
# 0  https://play-lh.googleusercontent.com/a/ACg8oc...
# 1  https://play-lh.googleusercontent.com/a/ACg8oc...
# 2  https://play-lh.googleusercontent.com/a-/ALV-U...
# 3  https://play-lh.googleusercontent.com/a-/ALV-U...
# 4  https://play-lh.googleusercontent.com/a/ACg8oc...
#
#                                              content  score  thumbsUpCount  \
# 0  mantap bos.... terimakasih semoga orderan nya ...      5              0
# 1                 semua menjadi terjangkau dan mudah      5              0
# 2                                               Good      5              0
# 3  pemesanan dengan driver reguler selalu terlamb...      3              0
# 4                                              mntap      5              0
#
#   reviewCreatedVersion                  at  \
# 0               5.38.1 2025-11-09 12:04:20
# 1                 None 2025-11-09 12:02:48
# 2               5.38.1 2025-11-09 11:49:00
# 3               5.38.1 2025-11-09 11:46:39
# 4                 None 2025-11-09 11:45:42
#
#                                         replyContent           repliedAt  \
# 0                                               None                 NaT
# 1                                               None                 NaT
# 2                                               None                 NaT
# 3  Hai Kak Kurni, mohon maaf atas ketidaknyamanan... 2025-11-09 12:06:22
# 4                                               None                 NaT
#
#   appVersion
# 0     5.38.1
# 1       None
# 2     5.38.1
# 3     5.38.1
# 4       None

# %%
app_reviews_df.to_csv('ulasan_gojek.csv', index=False, header=True)
print("Data saved to ulasan_gojek.csv")
# Out:
# Data saved to ulasan_gojek.csv
